# %%
# %pip install geopandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

gdf = gpd.read_file('../assets/underground.geojson')

gdf
# Out:
#                  fromStation                toStation line     km  time  \
# 0      Kurt-Schumacher-Platz        Afrikanische Str.   U6  0.621     1
# 1          Afrikanische Str.                 Rehberge   U6  0.588     1
# 2                   Rehberge                  Seestr.   U6  1.119     2
# 3                     Seestr             Leopoldplatz   U6  0.557     2
# 4               Leopoldplatz                  Wedding   U6  0.547     1
# ..                       ...                      ...  ...    ...   ...
# 189            Berliner Str.              Bundesplatz   U9  1.110     2
# 190              Bundesplatz  Friedrich-Wilhelm-Platz   U9  0.615     1
# 191  Friedrich-Wilhelm-Platz  Walther-Schreiber-Platz   U9  0.676     1
# 192  Walther-Schreiber-Platz               Schloßstr.   U9  0.565     2
# 193               Schloßstr.         Rathaus Steglitz   U9  0.594     1
#
#                                               geometry
# ...

# %%
coloursCodes = {'U1': '#7DAD4C', 
               'U2': '#DA421E', 
               'U3': '#16683D', 
               'U4': '#F0D722', 
               'U5': '#7E5330', 
               'U6': '#8C6DAB', 
               'U7': '#009BD5', 
               'U8': '#224F86', 
               'U9': '#F3791D'}

gdf['colour'] = coloursCodes[gdf['line']]
